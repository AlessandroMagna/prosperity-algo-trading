# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error


data_0 = pd.read_csv('/Users/Orestis/Desktop/Prosperity/DATA/round-3-island-data-bottle/prices_round_3_day_0.csv', sep =";")
data_1 = pd.read_csv('/Users/Orestis/Desktop/Prosperity/DATA/round-3-island-data-bottle/prices_round_3_day_1.csv', sep =";")
data_2 = pd.read_csv('/Users/Orestis/Desktop/Prosperity/DATA/round-3-island-data-bottle/prices_round_3_day_2.csv', sep =";")

data=[data_0, data_1, data_2]
data= pd.concat(data)
data.head()
# Out:
#    day  timestamp       product  bid_price_1  bid_volume_1  bid_price_2  \
# 0    0          0     CHOCOLATE         7999           111          NaN
# 1    0          0  STRAWBERRIES         3999           210          NaN
# 2    0          0         ROSES        14999            72          NaN
# 3    0          0   GIFT_BASKET        71348            19      71347.0
# 4    0        100   GIFT_BASKET        71344             1      71343.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           NaN          NaN           NaN         8001           111
# 1           NaN          NaN           NaN         4001           210
# 2           NaN          NaN           NaN        15001            72
# 3          24.0          NaN           NaN        71362            19
# 4          12.0      71342.0          20.0        71355             1
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...
